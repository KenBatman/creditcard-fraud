# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data/creditcard.csv')
print(df.shape)
df
# Out:
# (284807, 31)
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
print(df.info())
print(df.isnull().sum())
print(df['Class'].value_counts(normalize=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB
# None
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
print(df.isnull().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
tar_col = "Class"
num_cols = df.select_dtypes(include=['number']).columns.tolist() #lấy tất cả các cột kiểu số trong df (numeric) 
# Loại bỏ cột Class khỏi danh sách
num_cols = [col for col in num_cols if col != tar_col]
print(num_cols)
# Out:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

# %%
constant_cols = [col for col in df.columns if df[col].nunique() == 1] #check duyệt qua từng cột xem có cột nào có 1 giá trị hay thôi, nunique (đếm số lượng giá trị duy nhất)
if constant_cols:
    print("Các cột hằng tìm thấy:", constant_cols)
else:
    print("Không có cột hằng nào.")
# Out:
# Không có cột hằng nào.

# %%
#2. Kiểm tra hàng trùng lặp (duplicate rows)
duplicate_count = df.duplicated().sum()
if duplicate_count > 0:
    print(f"Số hàng trùng lặp: {duplicate_count}")
else:
    print("Không có hàng trùng lặp.")
# Out:
# Số hàng trùng lặp: 1081

# %%
#Xóa các hàng trùng lặp và cập nhật DataFrame
df = df.drop_duplicates()
# Kiểm tra lại số lượng hàng sau khi xóa
print("Số hàng sau khi xóa trùng lặp:", df.shape[0])
# Out:
# Số hàng sau khi xóa trùng lặp: 283726

# %%
Q1 = df[num_cols].quantile(0.25) #xem lại công thức tính giá trị ngoại lai
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

# Xác định outliers (giá trị nhỏ hơn Q1 - 1.5*IQR hoặc lớn hơn Q3 + 1.5*IQR)
outliers_iqr = ((df[num_cols] < (Q1 - 1.5 * IQR)) | 
                (df[num_cols] > (Q3 + 1.5 * IQR)))

# Đếm số lượng outlier trên mỗi cột
outlier_counts_iqr = outliers_iqr.sum()
print("Số lượng giá trị ngoại lai (IQR) trên mỗi cột:")
print(outlier_counts_iqr[outlier_counts_iqr > 0])
# Out:
# Số lượng giá trị ngoại lai (IQR) trên mỗi cột:
# V1         6948
# V2        13390
# V3         3306
# V4        11094
# V5        12221
# V6        22886
# V7         8839
# V8        23904
# V9         8199
# V10        9345
# V11         735
# V12       15282
# V13        3362
# V14       14060
# V15        2884
# V16        8180
# V17        7353
# V18        7468
# V19       10150
# V20       27553
# V21       14401
# V22        1298
# V23       18467
# V24        4758
# V25        5333
# V26        5665
# V27       38799
# V28       30094
# Amount    31685
# dtype: int64

# %%
# Loại bỏ cột mục tiêu nếu có
features = [col for col in num_cols if col != "Class"]

for col in features:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot của {col}")
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler #scale lại dữ liệu đưa các giá trị của Amount và Time về cùng thang đo với các feature khác (V1–V28), giúp mô hình học hiệu quả hơn
df['normAmount'] = StandardScaler().fit_transform(df['Amount'].values.reshape(-1,1))
df['normTime'] = StandardScaler().fit_transform(df['Time'].values.reshape(-1,1))
df = df.drop(['Amount','Time'], axis=1)
# Out:
# C:\Users\DLCH\AppData\Local\Temp\ipykernel_16540\2807827154.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normAmount'] = StandardScaler().fit_transform(df['Amount'].values.reshape(-1,1))
# C:\Users\DLCH\AppData\Local\Temp\ipykernel_16540\2807827154.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normTime'] = StandardScaler().fit_transform(df['Time'].values.reshape(-1,1))

# %%
num_cols = df.select_dtypes(include=['number']).columns.tolist()
num_cols = [col for col in num_cols if col != tar_col]
num_cols = np.array(num_cols)

# %%
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V22       V23  \
# 0       0.239599  0.098698  0.363787  0.090794  ...  0.277838 -0.110474
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.771679  0.909412
# 3       0.237609  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321
# 4       0.592941 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.111864  1.014480
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.924384  0.012463
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.578229 -0.037501
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.800049 -0.163298
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.643078  0.376777
#
#              V24       V25       V26       V27       V28  Class  normAmount  \
# 0       0.066928  0.128539 -0.189115  0.133558 -0.021053      0    0.244200
# 1      -0.339846  0.167170  0.125895 -0.008983  0.014724      0   -0.342584
# 2      -0.689281 -0.327642 -0.139097 -0.055353 -0.059752      0    1.158900
# 3      -1.175575  0.647376 -0.221929  0.062723  0.061458      0    0.139886
# 4       0.141267 -0.206010  0.502292  0.219422  0.215153      0   -0.073813
# ...          ...       ...       ...       ...       ...    ...         ...
# 284802 -0.509348  1.436807  0.250034  0.943651  0.823731      0   -0.350252
# 284803 -1.016226 -0.606624 -0.395255  0.068472 -0.053527      0   -0.254325
# 284804  0.640134  0.265745 -0.087371  0.004455 -0.026561      0   -0.082239
# 284805  0.123205 -0.569159  0.546668  0.108821  0.104533      0   -0.313391
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649      0    0.513290
#
#         normTime
# 0      -1.996823
# 1      -1.996823
# 2      -1.996802
# 3      -1.996802
# 4      -1.996781
# ...          ...
# 284802  1.642235
# 284803  1.642257
# 284804  1.642278
# 284805  1.642278
# 284806  1.642362
#
# [283726 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split #tìm hiểu lại cách x train y train và x test y 

# 1) Tách feature và target
X = df.drop(tar_col, axis=1)
y = df[tar_col]

# 2) Chia train/test
X_train, X_test, y_train, y_test = train_test_split( 
    X, y,
    test_size=0.2,        # 20% dùng để test
    stratify=y,           # giữ nguyên tỷ lệ lớp (rất quan trọng khi imbalanced)
    random_state=42       # để kết quả có thể tái lập
)

# 3) Kiểm tra kích thước và phân bố
print("Train shape:", X_train.shape, y_train.shape)
print("Test shape:",  X_test.shape,  y_test.shape)
print("Train class ratio:\n", y_train.value_counts(normalize=True))
print("Test  class ratio:\n", y_test.value_counts(normalize=True))
# Out:
# Train shape: (226980, 30) (226980,)
# Test shape: (56746, 30) (56746,)
# Train class ratio:
#  Class
# 0    0.998335
# 1    0.001665
# Name: proportion, dtype: float64
# Test  class ratio:
#  Class
# 0    0.998326
# 1    0.001674
# Name: proportion, dtype: float64

# %%
from imblearn.over_sampling import SMOTE #tìm hiểu lại tại sao và smote là gì
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# Ví dụ dùng RobustScaler để giảm ảnh hưởng outlier
pipeline = Pipeline([
    ('scaler', RobustScaler()),
])

# %%
# Tạo preprocessor: áp dụng RobustScaler cho các cột số
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer([
    ('num', pipeline, num_cols)
])

preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scaler', RobustScaler())]),
#                                  array(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',
#        'normAmount', 'normTime'], dtype='<U10'))])

# %%
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scaler', RobustScaler())]),
#                                  array(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',
#        'normAmount', 'normTime'], dtype='<U10'))])

# %%
X_train
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0       2.238954 -1.724499 -2.151484 -2.577803  0.993668  3.565492 -1.785957
# 1      -1.315062  1.630783  0.597001 -0.038359 -0.404580 -0.965712  0.212249
# 2       1.908801  0.021184 -2.087997  0.129310  1.161468  0.605244 -0.022371
# 3       1.811257  0.316556  0.316751  3.880231  0.048454  1.020163 -0.734868
# 4       1.358817 -1.120881  0.550266 -1.547659 -1.194950  0.275448 -1.201843
# ...          ...       ...       ...       ...       ...       ...       ...
# 453199 -2.799988  0.728711 -5.166481  1.799150 -1.032709 -2.696629 -1.857320
# 453200 -1.233957  1.653888 -3.028534  2.513010  3.497817 -3.111859 -5.707580
# 453201  0.036409  1.025933 -2.030381  1.955565 -1.052080 -0.838244 -2.533695
# 453202  1.128816  1.291563 -1.358572  2.101199  0.847358 -1.063046  0.390835
# 453203 -3.083993  0.996149 -1.398442  0.761141 -1.183252 -0.605128 -1.818755
#
#               V8        V9       V10  ...       V21       V22       V23  \
# 0       0.860122 -1.264003  1.567867  ... -0.149574 -0.049333  0.278442
# 1       0.735381 -1.267926 -0.482635  ... -0.238898 -0.946773  0.323904
# 2       0.180296  0.283819 -0.497766  ...  0.293609  1.095842 -0.044874
# 3       0.233651  0.681423  1.146705  ...  0.138869  0.700422  0.174064
# 4       0.212889 -2.094285  1.492821  ... -0.340972 -0.636442  0.252758
# ...          ...       ...       ...  ...       ...       ...       ...
# 453199  0.963061 -1.746818 -5.336439  ...  0.634961 -0.282435 -0.166193
# 453200 -2.094295 -1.066726 -3.001922  ... -0.774127 -0.311094 -5.660984
# 453201  0.511091 -0.905357 -3.019005  ...  0.580502  0.489605 -0.128521
# 453202 -0.100586 -0.035883 -2.153760  ... -0.355347 -0.686264 -0.120860
# 453203  0.285160 -0.333862 -2.729835  ...  0.472702  0.513417 -0.218630
#
#              V24       V25       V26       V27       V28  normAmount  normTime
# 0       0.684735 -0.219028 -0.159167  0.037920 -0.049932   -0.225531  1.047534
# 1       0.515632 -0.713000 -0.266503 -0.017794  0.051058   -0.325411 -0.296857
# 2      -1.689517  0.106098  0.007758  0.045164 -0.053068   -0.293622  0.680376
# 3       0.702997 -0.212523 -0.010018 -0.017740 -0.038006   -0.284237 -0.073062
# 4      -0.344160 -0.064282 -0.439622  0.062524  0.013095   -0.257480 -1.375058
# ...          ...       ...       ...       ...       ...         ...       ...
# 453199 -0.213093 -0.099081  0.654353  0.728160 -0.147405    0.778355  1.578251
# 453200  0.680141 -1.534645 -0.661960  0.740913  0.506934   -0.344732  1.021943
# 453201 -0.509379  0.590253 -0.250185  0.576522  0.163023   -0.318514 -0.520598
# 453202 -0.126090  0.671344 -0.323531  0.106082  0.126758   -0.349333 -0.374579
# 453203 -0.341307  0.100618  0.426741 -1.102913  0.416217   -0.062367 -0.733944
#
# [453204 rows x 30 columns]

# %%
X_train_tf = preprocessor.transform(X_train)

# %%
X_train_tf
# Out:
# array([[ 7.95683090e-01, -9.59338699e-01, -1.44450910e-01, ...,
#         -3.40986648e-01,  9.34323846e-02,  7.50583041e-01],
#        [-1.62991281e-01,  2.21273850e-01,  3.84463848e-01, ...,
#          4.80286106e-02, -1.64486372e-01,  2.44571107e-02],
#        [ 7.06626416e-01, -3.45090610e-01, -1.32233536e-01, ...,
#         -3.53066764e-01, -8.23978756e-02,  5.52275687e-01],
#        ...,
#        [ 2.01559843e-01,  8.44722023e-03, -1.21145984e-01, ...,
#          4.79321977e-01, -1.46676138e-01, -9.63883591e-02],
#        [ 4.96230138e-01,  1.01913558e-01,  8.13608192e-03, ...,
#          3.39628119e-01, -2.26258998e-01, -1.75215089e-02],
#        [-6.40149869e-01, -2.03271591e-03,  4.63473076e-04, ...,
#          1.45462948e+00,  5.14766047e-01, -2.11619848e-01]],
#       shape=(453204, 30))

# %%
 X_test_tf = preprocessor.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train_tf, y_train)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(X_test_tf)

# %%
print(predictions)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.97

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_auc_score

probs = model.predict_proba(X_test)[:, 1]
auc = roc_auc_score(y_test, probs)
print(f"AUC: {auc:.2f}")
# Out:
# AUC: 0.94
# D:\creditcard-fraud\venv\lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56651
#            1       0.05      0.87      0.10        95
#
#     accuracy                           0.97     56746
#    macro avg       0.53      0.92      0.54     56746
# weighted avg       1.00      0.97      0.99     56746
